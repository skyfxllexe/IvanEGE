# %% [markdown]
# ![{BDD6394E-8F36-482B-839A-DB89D76D2649}.png](attachment:{BDD6394E-8F36-482B-839A-DB89D76D2649}.png)

# %%
s = '7'*85

while '333' in s or '777' in s:
    if '333' in s:
        s = s.replace('333','7', 1)
    else:
        s= s.replace('777','3', 1)
print(s)
# Out:
# 377

# %% [markdown]
# ![{6414EE63-E3E2-45EC-BAD1-C6B6C32B8A74}.png](attachment:{6414EE63-E3E2-45EC-BAD1-C6B6C32B8A74}.png)

# %%
for x in range(100):
    for y in range(100):
        for z in range(100):
            s = '0' + '1'*x + '2'*y  + '3'*z
            while '01' in s or '02' in s or '03' in s:
                s = s.replace('01','2302',1)
                s = s.replace('02','10',1)
                s = s.replace('03','201',1)
            if s.count('1') == 50 and s.count('2') == 12 and s.count('3') == 7:
                print(s, x)
# Out:
# 2312311111111111111111111111111111111111111111111223122312231223122310 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6     s = s.replace('01','2302',1)
#       7     s = s.replace('02','10',1)
# ----> 8     s = s.replace('03','201',1)
#       9 if s.count('1') == 50 and s.count('2') == 12 and s.count('3') == 7:
#      10     print(s, s.count('1'))
#
# KeyboardInterrupt:
